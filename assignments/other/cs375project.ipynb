# %% [markdown]
# ## Imports

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import sklearn
import numpy as np
import cv2
# Out:
# 2024-11-20 02:37:20.274862: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-20 02:37:20.284991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732070240.297649    4388 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732070240.301619    4388 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Dataset
# Load CIFAR-10 dataset

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

x_train = x_train[:2500]
y_train = y_train[:2500]

x_test = x_test[:500]
y_test = y_test[:500]

x_train.shape,x_test.shape
# Out:
# ((2500, 32, 32, 3), (500, 32, 32, 3))

# %% [markdown]
# We can infer that our dataset contains 50000 training and 10000 testing images, all of size 32x32px with 3 color channels.

# %% [markdown]
# ## Pre-Processing
# Normalization

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# Reshape training set from (50000, 32, 32, 3) to (50000, 3072)

# %%
nsamples, nx, ny, nrgb = x_train.shape
x_train2 = x_train.reshape((nsamples, nx*ny*nrgb))

# %% [markdown]
# Reshape test set from (10000, 32, 32, 3) to (10000, 3072)

# %%
nsamples, nx, ny, nrgb = x_test.shape
x_test2 = x_test.reshape((nsamples, nx*ny*nrgb))

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

# %% [markdown]
# Train model

# %%
model.fit(x_train2,y_train.ravel())
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test2)
y_pred
# Out:
# array([6, 1, 8, 8, 4, 6, 5, 6, 2, 8, 8, 9, 5, 7, 1, 5, 5, 4, 9, 6, 4, 0,
#        2, 1, 2, 1, 6, 9, 1, 6, 3, 2, 4, 6, 9, 1, 4, 9, 2, 5, 0, 6, 1, 4,
#        8, 9, 6, 8, 4, 4, 9, 1, 6, 3, 8, 8, 3, 1, 8, 2, 7, 6, 6, 9, 4, 4,
#        1, 0, 6, 9, 0, 4, 8, 8, 9, 2, 9, 5, 6, 8, 8, 1, 2, 0, 0, 9, 5, 8,
#        8, 8, 8, 6, 8, 2, 4, 2, 6, 0, 3, 9, 2, 4, 5, 3, 7, 1, 4, 6, 3, 5,
#        4, 5, 6, 2, 9, 4, 0, 9, 3, 5, 8, 4, 1, 2, 8, 4, 8, 5, 7, 0, 2, 9,
#        9, 7, 3, 3, 9, 0, 6, 8, 2, 8, 0, 7, 1, 7, 6, 5, 5, 5, 9, 9, 3, 0,
#        7, 4, 2, 9, 6, 7, 0, 1, 1, 4, 8, 7, 8, 6, 7, 9, 8, 7, 2, 0, 7, 9,
#        0, 4, 2, 9, 0, 0, 2, 2, 2, 8, 6, 3, 9, 8, 5, 4, 5, 3, 7, 4, 7, 0,
#        5, 5, 7, 9, 0, 7, 1, 5, 0, 5, 7, 8, 7, 1, 0, 9, 0, 2, 0, 9, 0, 4,
#        7, 6, 8, 6, 9, 9, 9, 3, 0, 7, 5, 9, 7, 4, 8, 0, 2, 9, 8, 3, 1, 3,
#        7, 9, 0, 3, 4, 8, 5, 6, 4, 5, 6, 3, 2, 0, 3, 9, 8, 7, 5, 1, 2, 3,
#        0, 8, 8, 7, 7, 0, 4, 2, 6, 6, 9, 7, 9, 4, 7, 5, 9, 4, 3, 1, 9, 9,
# ...

# %%
accuracy_score(y_pred,y_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40        58
#            1       0.49      0.43      0.46        46
#            2       0.27      0.29      0.28        48
#            3       0.12      0.19      0.15        32
#            4       0.20      0.14      0.17        56
#            5       0.29      0.32      0.30        44
#            6       0.41      0.47      0.44        47
#            7       0.26      0.27      0.26        44
#            8       0.49      0.46      0.47        61
#            9       0.50      0.44      0.47        64
#
#     accuracy                           0.35       500
#    macro avg       0.34      0.34      0.34       500
# weighted avg       0.36      0.35      0.35       500

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[23,  0, 10,  2,  2,  3,  2,  6, 10,  0],
#        [ 2, 20,  5,  2,  2,  1,  1,  2,  5,  6],
#        [ 2,  2, 14,  5,  7,  6,  7,  0,  0,  5],
#        [ 1,  3,  3,  6,  3,  2,  5,  7,  1,  1],
#        [ 2,  2,  6,  9,  8,  7, 12,  8,  2,  0],
#        [ 2,  1,  7,  9,  3, 14,  2,  3,  3,  0],
#        [ 3,  1,  3,  7,  6,  3, 22,  1,  0,  1],
#        [ 1,  2,  1,  6,  6,  7,  1, 12,  3,  5],
#        [10,  4,  1,  1,  1,  4,  0,  2, 28, 10],
#        [11,  6,  1,  2,  2,  1,  2,  6,  5, 28]])
